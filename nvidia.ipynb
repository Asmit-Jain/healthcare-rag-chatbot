# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)

completion = client.chat.completions.create(
  model="meta/llama-3.3-70b-instruct",
  messages=[{"role":"user","content":"What is llm?"}],
  temperature=0.2,
  top_p=0.7,
  max_tokens=1024,
  stream=False
)

print(completion.choices[0].message)

# %%
from openai import OpenAI
import json

client = OpenAI(
  base_url="https://integrate.api.nvidia.com/v1",
  api_key="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"
)

completion = client.chat.completions.create(
  model="qwen/qwen3-next-80b-a3b-instruct",
  messages=[{"role":"user","content":"what is llm?"}],
  temperature=0.6,
  top_p=0.7,
  max_tokens=4096,
  stream=False
)


message = completion.choices[0].message

if message.content:
  print(message.content)
# Out:
# **LLM** stands for **Large Language Model**.
#
# ### What is a Large Language Model (LLM)?
#
# An **LLM** is a type of artificial intelligence (AI) model designed to understand, generate, and manipulate human language. These models are “large” because they typically have **billions or even trillions of parameters** — the internal variables that the model learns during training to recognize patterns in text.
#
# ### Key Characteristics of LLMs:
#
# 1. **Trained on Massive Text Datasets**
#    LLMs are trained on vast amounts of text from books, websites, articles, code, and other sources — often totaling hundreds of gigabytes or terabytes of data.
#
# 2. **Transformer Architecture**
#    Most modern LLMs are built using the **transformer** neural network architecture, introduced in the 2017 paper “Attention Is All You Need.” Transformers excel at understanding context and long-range dependencies in text.
#
# 3. **Generative Capabilities**
# ...
